# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
from IPython.display import display

def gradient_func(val):
    return '<span style="background: linear-gradient(90deg, #d65f5f {0}%, transparent 0%)">{0:.3f}</span>'.format(val)

# %%
summary = pd.read_table('mapping_star.txt', sep='\t')
summary.set_index(['sample_id', 'map_step'], inplace=True)
display(summary.style.set_caption('Summary'))
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357" ><caption>Summary</caption>
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Started job on</th>
#         <th class="col_heading level0 col1" >Started mapping on</th>
#         <th class="col_heading level0 col2" >Finished on</th>
#         <th class="col_heading level0 col3" >Mapping speed, Million of reads per hour</th>
#         <th class="col_heading level0 col4" >Number of input reads</th>
#         <th class="col_heading level0 col5" >Average input read length</th>
#         <th class="col_heading level0 col6" >Uniquely mapped reads number</th>
#         <th class="col_heading level0 col7" >Uniquely mapped reads %</th>
#         <th class="col_heading level0 col8" >Average mapped length</th>
#         <th class="col_heading level0 col9" >Number of splices: Total</th>
#         <th class="col_heading level0 col10" >Number of splices: Annotated (sjdb)</th>
#         <th class="col_heading level0 col11" >Number of splices: GT/AG</th>
#         <th class="col_heading level0 col12" >Number of splices: GC/AG</th>
#         <th class="col_heading level0 col13" >Number of splices: AT/AC</th>
#         <th class="col_heading level0 col14" >Number of splices: Non-canonical</th>
#         <th class="col_heading level0 col15" >Mismatch rate per base, %</th>
#         <th class="col_heading level0 col16" >Deletion rate per base</th>
#         <th class="col_heading level0 col17" >Deletion average length</th>
#         <th class="col_heading level0 col18" >Insertion rate per base</th>
#         <th class="col_heading level0 col19" >Insertion average length</th>
#         <th class="col_heading level0 col20" >Number of reads mapped to multiple loci</th>
#         <th class="col_heading level0 col21" >% of reads mapped to multiple loci</th>
#         <th class="col_heading level0 col22" >Number of reads mapped to too many loci</th>
#         <th class="col_heading level0 col23" >% of reads mapped to too many loci</th>
#         <th class="col_heading level0 col24" >% of reads unmapped: too many mismatches</th>
#         <th class="col_heading level0 col25" >% of reads unmapped: too short</th>
#         <th class="col_heading level0 col26" >% of reads unmapped: other</th>
#         <th class="col_heading level0 col27" >Number of chimeric reads</th>
#         <th class="col_heading level0 col28" >% of chimeric reads</th>
#     </tr>    <tr>
#         <th class="index_name level0" >sample_id</th>
#         <th class="index_name level1" >map_step</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357level0_row0" class="row_heading level0 row0" rowspan=3>ECHO1710-A07_lncRNA_A07-05</th>
#         <th id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357level1_row0" class="row_heading level1 row0" >rRNA</th>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col0" class="data row0 col0" >Jan 03 18:04:57</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col1" class="data row0 col1" >Jan 03 18:04:58</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col2" class="data row0 col2" >Jan 03 19:10:09</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col3" class="data row0 col3" >73.72</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col4" class="data row0 col4" >80087412</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col5" class="data row0 col5" >257</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col6" class="data row0 col6" >52252</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col7" class="data row0 col7" >0.07%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col8" class="data row0 col8" >254.73</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col9" class="data row0 col9" >553</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col10" class="data row0 col10" >0</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col11" class="data row0 col11" >148</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col12" class="data row0 col12" >234</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col13" class="data row0 col13" >0</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col14" class="data row0 col14" >171</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col15" class="data row0 col15" >0.09%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col16" class="data row0 col16" >0.01%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col17" class="data row0 col17" >1.16</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col18" class="data row0 col18" >0.00%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col19" class="data row0 col19" >2.1</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col20" class="data row0 col20" >3230206</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col21" class="data row0 col21" >4.03%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col22" class="data row0 col22" >464075</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col23" class="data row0 col23" >0.58%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col24" class="data row0 col24" >0.00%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col25" class="data row0 col25" >1.58%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col26" class="data row0 col26" >93.75%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col27" class="data row0 col27" >0</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row0_col28" class="data row0 col28" >0.00%</td>
#     </tr>    <tr>
#         <th id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357level1_row1" class="row_heading level1 row1" >genome</th>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col0" class="data row1 col0" >Jan 03 20:51:59</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col1" class="data row1 col1" >Jan 03 20:53:52</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col2" class="data row1 col2" >Jan 04 00:03:28</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col3" class="data row1 col3" >24.31</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col4" class="data row1 col4" >76823641</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col5" class="data row1 col5" >256</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col6" class="data row1 col6" >22978040</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col7" class="data row1 col7" >29.91%</td>
#         <td id="T_e8748fcc_0ff1_11e9_a7dd_679a223a8357row1_col8" class="data row1 col8" >265.95</td>
#         <td id="T_e8748fcc_0ff1_11e9_a

# %%
summary_counts = summary.reindex(columns=[
                                 'Number of input reads', 
                                 'Uniquely mapped reads number',
                                 'Number of reads mapped to multiple loci', 
                                 'Number of reads mapped to too many loci'
                                ])
for item in ('too many mismatches', 'too short', 'other'):
    summary_counts['Number of reads unmapped: {}'.format(item)] = \
        (summary['% of reads unmapped: {}'.format(item)]\
        .str.strip('%').astype('float')*0.01*summary_counts['Number of input reads']).astype('int')

display(summary_counts.style.set_caption('Read counts summary'))
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_047e8902_0ff2_11e9_a7dd_679a223a8357" ><caption>Read counts summary</caption>
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Number of input reads</th>
#         <th class="col_heading level0 col1" >Uniquely mapped reads number</th>
#         <th class="col_heading level0 col2" >Number of reads mapped to multiple loci</th>
#         <th class="col_heading level0 col3" >Number of reads mapped to too many loci</th>
#         <th class="col_heading level0 col4" >Number of reads unmapped: too many mismatches</th>
#         <th class="col_heading level0 col5" >Number of reads unmapped: too short</th>
#         <th class="col_heading level0 col6" >Number of reads unmapped: other</th>
#     </tr>    <tr>
#         <th class="index_name level0" >sample_id</th>
#         <th class="index_name level1" >map_step</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level0_row0" class="row_heading level0 row0" rowspan=3>ECHO1710-A07_lncRNA_A07-05</th>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level1_row0" class="row_heading level1 row0" >rRNA</th>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row0_col0" class="data row0 col0" >80087412</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row0_col1" class="data row0 col1" >52252</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row0_col2" class="data row0 col2" >3230206</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row0_col3" class="data row0 col3" >464075</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row0_col4" class="data row0 col4" >0</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row0_col5" class="data row0 col5" >1265381</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row0_col6" class="data row0 col6" >75081948</td>
#     </tr>    <tr>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level1_row1" class="row_heading level1 row1" >genome</th>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row1_col0" class="data row1 col0" >76823641</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row1_col1" class="data row1 col1" >22978040</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row1_col2" class="data row1 col2" >4899206</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row1_col3" class="data row1 col3" >2048157</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row1_col4" class="data row1 col4" >0</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row1_col5" class="data row1 col5" >45264489</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row1_col6" class="data row1 col6" >1636343</td>
#     </tr>    <tr>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level1_row2" class="row_heading level1 row2" >circRNA</th>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row2_col0" class="data row2 col0" >49121103</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row2_col1" class="data row2 col1" >227802</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row2_col2" class="data row2 col2" >1584578</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row2_col3" class="data row2 col3" >182979</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row2_col4" class="data row2 col4" >0</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row2_col5" class="data row2 col5" >46719081</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row2_col6" class="data row2 col6" >407705</td>
#     </tr>    <tr>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level0_row3" class="row_heading level0 row3" rowspan=3>ECHO1710-A07_lncRNA_A07-07</th>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level1_row3" class="row_heading level1 row3" >rRNA</th>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row3_col0" class="data row3 col0" >76796788</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row3_col1" class="data row3 col1" >38155</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row3_col2" class="data row3 col2" >1497670</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row3_col3" class="data row3 col3" >336606</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row3_col4" class="data row3 col4" >0</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row3_col5" class="data row3 col5" >890842</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row3_col6" class="data row3 col6" >74032103</td>
#     </tr>    <tr>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level1_row4" class="row_heading level1 row4" >genome</th>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row4_col0" class="data row4 col0" >75269917</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row4_col1" class="data row4 col1" >10275298</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row4_col2" class="data row4 col2" >4766143</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row4_col3" class="data row4 col3" >2420727</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row4_col4" class="data row4 col4" >0</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row4_col5" class="data row4 col5" >56166412</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row4_col6" class="data row4 col6" >1640884</td>
#     </tr>    <tr>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level1_row5" class="row_heading level1 row5" >circRNA</th>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row5_col0" class="data row5 col0" >60353764</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row5_col1" class="data row5 col1" >200406</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row5_col2" class="data row5 col2" >1982230</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row5_col3" class="data row5 col3" >233340</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row5_col4" class="data row5 col4" >0</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row5_col5" class="data row5 col5" >57305898</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row5_col6" class="data row5 col6" >633714</td>
#     </tr>    <tr>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level0_row6" class="row_heading level0 row6" rowspan=3>ECHO1710-A07_lncRNA_A07-08</th>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level1_row6" class="row_heading level1 row6" >rRNA</th>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row6_col0" class="data row6 col0" >72298680</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row6_col1" class="data row6 col1" >80093</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row6_col2" class="data row6 col2" >5903781</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row6_col3" class="data row6 col3" >445234</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row6_col4" class="data row6 col4" >0</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row6_col5" class="data row6 col5" >1937604</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row6_col6" class="data row6 col6" >63933722</td>
#     </tr>    <tr>
#         <th id="T_047e8902_0ff2_11e9_a7dd_679a223a8357level1_row7" class="row_heading level1 row7" >genome</th>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row7_col0" class="data row7 col0" >66346179</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row7_col1" class="data row7 col1" >13848536</td>
#         <td id="T_047e8902_0ff2_11e9_a7dd_679a223a8357row7_col2" class="data row7 col2" >5590057</td>

# %%
summary_percent = summary_counts.copy()
summary_percent = 100.0*summary_percent.div(summary_percent['Number of input reads'], axis=0)
summary_percent.drop(columns=['Number of input reads'], inplace=True)
display(summary_percent.style.format(gradient_func).set_caption('Read percent summary'))
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357" ><caption>Read percent summary</caption>
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uniquely mapped reads number</th>
#         <th class="col_heading level0 col1" >Number of reads mapped to multiple loci</th>
#         <th class="col_heading level0 col2" >Number of reads mapped to too many loci</th>
#         <th class="col_heading level0 col3" >Number of reads unmapped: too many mismatches</th>
#         <th class="col_heading level0 col4" >Number of reads unmapped: too short</th>
#         <th class="col_heading level0 col5" >Number of reads unmapped: other</th>
#     </tr>    <tr>
#         <th class="index_name level0" >sample_id</th>
#         <th class="index_name level1" >map_step</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357level0_row0" class="row_heading level0 row0" rowspan=3>ECHO1710-A07_lncRNA_A07-05</th>
#         <th id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357level1_row0" class="row_heading level1 row0" >rRNA</th>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row0_col0" class="data row0 col0" ><span style="background: linear-gradient(90deg, #d65f5f 0.06524371145867469%, transparent 0%)">0.065</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row0_col1" class="data row0 col1" ><span style="background: linear-gradient(90deg, #d65f5f 4.033350459620296%, transparent 0%)">4.033</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row0_col2" class="data row0 col2" ><span style="background: linear-gradient(90deg, #d65f5f 0.5794606023728174%, transparent 0%)">0.579</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row0_col3" class="data row0 col3" ><span style="background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0%)">0.000</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row0_col4" class="data row0 col4" ><span style="background: linear-gradient(90deg, #d65f5f 1.5799998631495296%, transparent 0%)">1.580</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row0_col5" class="data row0 col5" ><span style="background: linear-gradient(90deg, #d65f5f 93.74999906352323%, transparent 0%)">93.750</span></td>
#     </tr>    <tr>
#         <th id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357level1_row1" class="row_heading level1 row1" >genome</th>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row1_col0" class="data row1 col0" ><span style="background: linear-gradient(90deg, #d65f5f 29.910115819686283%, transparent 0%)">29.910</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row1_col1" class="data row1 col1" ><span style="background: linear-gradient(90deg, #d65f5f 6.3772114107426905%, transparent 0%)">6.377</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row1_col2" class="data row1 col2" ><span style="background: linear-gradient(90deg, #d65f5f 2.666050415392314%, transparent 0%)">2.666</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row1_col3" class="data row1 col3" ><span style="background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0%)">0.000</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row1_col4" class="data row1 col4" ><span style="background: linear-gradient(90deg, #d65f5f 58.91999963917357%, transparent 0%)">58.920</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row1_col5" class="data row1 col5" ><span style="background: linear-gradient(90deg, #d65f5f 2.1299992797789944%, transparent 0%)">2.130</span></td>
#     </tr>    <tr>
#         <th id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357level1_row2" class="row_heading level1 row2" >circRNA</th>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row2_col0" class="data row2 col0" ><span style="background: linear-gradient(90deg, #d65f5f 0.4637558729086356%, transparent 0%)">0.464</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row2_col1" class="data row2 col1" ><span style="background: linear-gradient(90deg, #d65f5f 3.225859973054758%, transparent 0%)">3.226</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row2_col2" class="data row2 col2" ><span style="background: linear-gradient(90deg, #d65f5f 0.37250588611579016%, transparent 0%)">0.373</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row2_col3" class="data row2 col3" ><span style="background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0%)">0.000</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row2_col4" class="data row2 col4" ><span style="background: linear-gradient(90deg, #d65f5f 95.10999987113482%, transparent 0%)">95.110</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row2_col5" class="data row2 col5" ><span style="background: linear-gradient(90deg, #d65f5f 0.8299996846569182%, transparent 0%)">0.830</span></td>
#     </tr>    <tr>
#         <th id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357level0_row3" class="row_heading level0 row3" rowspan=3>ECHO1710-A07_lncRNA_A07-07</th>
#         <th id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357level1_row3" class="row_heading level1 row3" >rRNA</th>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row3_col0" class="data row3 col0" ><span style="background: linear-gradient(90deg, #d65f5f 0.04968306747412405%, transparent 0%)">0.050</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row3_col1" class="data row3 col1" ><span style="background: linear-gradient(90deg, #d65f5f 1.950172707743975%, transparent 0%)">1.950</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row3_col2" class="data row3 col2" ><span style="background: linear-gradient(90deg, #d65f5f 0.43830739379360506%, transparent 0%)">0.438</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row3_col3" class="data row3 col3" ><span style="background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0%)">0.000</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row3_col4" class="data row3 col4" ><span style="background: linear-gradient(90deg, #d65f5f 1.1599990353763234%, transparent 0%)">1.160</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row3_col5" class="data row3 col5" ><span style="background: linear-gradient(90deg, #d65f5f 96.39999917704891%, transparent 0%)">96.400</span></td>
#     </tr>    <tr>
#         <th id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357level1_row4" class="row_heading level1 row4" >genome</th>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row4_col0" class="data row4 col0" ><span style="background: linear-gradient(90deg, #d65f5f 13.651267876381477%, transparent 0%)">13.651</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row4_col1" class="data row4 col1" ><span style="background: linear-gradient(90deg, #d65f5f 6.332068892808797%, transparent 0%)">6.332</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row4_col2" class="data row4 col2" ><span style="background: linear-gradient(90deg, #d65f5f 3.2160617368556417%, transparent 0%)">3.216</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row4_col3" class="data row4 col3" ><span style="background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0%)">0.000</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row4_col4" class="data row4 col4" ><span style="background: linear-gradient(90deg, #d65f5f 74.61999991311271%, transparent 0%)">74.620</span></td>
#         <td id="T_0c9cee62_0ff2_11e9_a7dd_679a223a8357row4_col5" class="data row4 col5" ><span style="background: linear-gradient(90deg, #d65f5f 2.1799997467779857%, transpare
